# %% [markdown]
# <a href="https://colab.research.google.com/github/Hussam3d/Hussam3d/blob/main/paython_WS_day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import * #import all functions from sympy library

# %% [markdown]
# 1. Factor $x^2-y^2$.
#
# 2. Solve $x^2-4x-3=0$.
# 3. Split $\fra{1}

# %%
n , x, y, = symbols("n x y ")
factor(x**2-y**2)
# Out:
# (x - y)*(x + y)

# %%
#symbolic computation
solve(x**2-4*x-3,x)
# Out:
# [2 - sqrt(7), 2 + sqrt(7)]

# %%
apart(1/((x+2)*(x+1)))
# Out:
# -1/(x + 2) + 1/(x + 1)

# %% [markdown]
# simplify $\cos(x)- cos(x)**3

# %%
trigsimp(cos(x)-cos(x)**3)
# Out:
# sin(x)**2*cos(x)

# %% [markdown]
# Fibd $\lim{x→

# %%
limit(x/sin(x), x, 0)
# Out:
# 1

# %% [markdown]
# fibd $\frac{d}-{dx} \ left (x^2-7x+8\right)

# %%
diff(5*x**7, x, 3)
# Out:
# 1050*x**4

# %%
diff(3* x**4* y**7, x, 2, y, 1)
# Out:
# 252*x**2*y**6

# %%
(exp(x)*cos(x).series(x,0,10))
# Out:
# (1 - x**2/2 + x**4/24 - x**6/720 + x**8/40320 + O(x**10))*exp(x)

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(-1, 10) # Adjusted range to avoid overflow and improve plot visibility
y1=np.exp(x)*np.cos(x)
y2=1+x-x**3 /3-x**4 / 6-x**5/30
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %% [markdown]
# Find $A=\int_{x=1}^3 x x^4

# %%
sym_x = symbols('x') # Use a distinct variable name for the SymPy symbol
integrate(sym_x**4, (sym_x, 1, 3))
# Out:
# 242/5

# %% [markdown]
# Find

# %%
summation(1/n**2, (n , 1, oo))
# Out:
# pi**2/6

# %%
summation(1/n, (n,1,oo))
# Out:
# oo

# %% [markdown]
# solve: $y=x$ and $x+2y=5$

# %%
solve([x-y, x+2*y-5], [x,y])
# Out:
# {x: 5/3, y: 5/3}

# %%
solve([x-y, x**2 + y**2 -1], [x,y])
# Out:
# [(-sqrt(2)/2, -sqrt(2)/2), (sqrt(2)/2, sqrt(2)/2)]

# %%
N(pi, 1000)
# Out:
# 3....

# %%
A=Matrix(([1,-1],[2,4])) # Example fix: Assuming a 2x2 matrix was intended. Adjust 0 as needed.

# %%
B=Matrix(([0,2],[3,3]))

# %%
A*B
# Out:
# Matrix([
# [-3, -1],
# [12, 16]])

# %%
A.row(0)
# Out:
# Matrix([[1, -1]])

# %%
A.col(1)
# Out:
# Matrix([
# [-1],
# [ 4]])

# %%
A.T
# Out:
# Matrix([
# [ 1, 2],
# [-1, 4]])

# %%
A.inv()
# Out:
# Matrix([
# [ 2/3, 1/6],
# [-1/3, 1/6]])
